# %%
from goes2go import GOES

# Change the current working directory to your desired directory
desired_directory = r'C:\Users\jinge\OneDrive\Documents\Research\Lightning Data'

# Initialize the GOES object for Geostationary Lightning Mapper
G = GOES(satellite=17, product="GLM-L2-LCFA", domain='C')

# Download data for the specified time range
G.timerange(start='2020-07-06 18:29', end='2020-07-06 18:59', save_dir=desired_directory)
# Out:
# domain argument is ignored for non-ABI products
# 📦 Finished downloading [90] files to [C:\Users\jinge\OneDrive\Documents\Research\Lightning Data\noaa-goes17\GLM-L2-LCFA].
#                                                  file product_mode satellite  \
# 0   noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 1   noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 2   noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 3   noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 4   noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# ..                                                ...          ...       ...
# 85  noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 86  noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# 87  noaa-goes17/GLM-L2-LCFA/2020/188/18/OR_GLM-L2-...  GLM-L2-LCFA       G17
# ...
